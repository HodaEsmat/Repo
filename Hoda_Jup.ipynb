# %% [markdown]
# # My Jupyter Notebook on IBM Watson Studio

# %% [markdown]
# **Hoda Esmat**
# **Data Scientist**

# %% [markdown]
# *I am interested in data science because it's my career*

# %% [markdown]
# ### My Code is supposed to add two numbers

# %%
1+1
# Out:
# 2

# %% [markdown]
# ![IMG_7581.JPG](attachment:IMG_7581.JPG)
# * One
# * Two
# * Three
#
#
# https://www.ibm.com/eg-en
